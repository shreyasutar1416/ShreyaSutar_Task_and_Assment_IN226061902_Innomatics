# %% [markdown]
# # 1. User Login Check
# Problem Statement:
# Given a username and password, check whether login is successful.
#
# Requirements:
# Print "Login Successful" if both username and password match
# Otherwise print "Invalid Credentials"
#
# Real-World Application: Authentication systems

# %%
#Given credentials
correct_username = "admin"
correct_password = "1234"

#Inputs
username = input("Enter Username:")
password = input("Enter Password:")

#checking 
if username==correct_username and password==correct_password:
    print("Login Successful!")
else:
    print("Invalid Credentials")
# Out:
# Enter Username: admin
# Enter Password: 1234
# Login Successful!

# %% [markdown]
# # 2. Pass / Fail Analyzer
# Problem Statement:
# Analyze student results.
#
# Requirements:
# A student passes if marks ≥ 50
# Count the total number of pass students
# Count the total number of fail students
# Print the final result clearly
#
# Real-World Application: Academic evaluation systems

# %%
#Given Credentials
marks = [45, 78, 90, 33, 60]

#assigning pass and fail count as zero or as initial
pass_count= 0
fail_count= 0

#checking
for mark in marks:
   if mark >= 50:
       pass_count += 1
   else:
       fail_count += 1
       
#Display Results      
print("Total Students:", len(marks))
print("Passed Students:", pass_count)
print("Failed Students:", fail_count)
# Out:
# Total Students: 5
# Passed Students: 3
# Failed Students: 2

# %% [markdown]
# # 3. Simple Data Cleaner
# Problem Statement:
# Clean and standardize user names.
#
#
# Requirements:
# Remove extra spaces
# Convert all names to lowercase
# Print the cleaned list
#
# Real-World Application: Data preprocessing before analysis

# %%
#Given Credentials
names = [" Alice ", "bob", " CHARLIE "]

#created List for Cleaned names
cleaned_names = []

#removing extra spaces and converting into lowercase 
for name in names:
    clean_name = name.strip().lower()
    cleaned_names.append(clean_name)

#printing the final List of cleaned names
print("cleaned_names:", cleaned_names)
# Out:
# cleaned_names: ['alice', 'bob', 'charlie']

# %% [markdown]
# # 4. Message Length Analyzer
# Problem Statement:
# Analyze message sizes.
#
#
# Requirements:
# Print the length of each message
# Flag messages longer than 10 characters
#
# Real-World Application: Text filtering and validation systems

# %%
messages = ["Hi", "Welcome to the platform", "OK"]

for message in messages:
    length = len(message)
    print(f"message: '{message}'| length: {length}")

    if length > 10:
       print("This message is longer than 10 characters")
# Out:
# message: 'Hi'| length: 2
# message: 'Welcome to the platform'| length: 23
# This message is longer than 10 characters
# message: 'OK'| length: 2

# %% [markdown]
# # 5. Error Message Detector
# Problem Statement:
# Detect error messages from system logs.
#
# Requirements:
# Count the number of "ERROR" entries
# Print the total error count
#
# Real-World Application: Monitoring and log analysis systems

# %%
#Given credentials
logs = ["INFO", "ERROR", "WARNING", "ERROR"]

#assigning initial error count as zero
error_count = 0

for log in logs:
    if log == "ERROR":
        error_count += 1

#display results
print("Total Error Messages:", error_count)
# Out:
# Total Error Messages: 2
